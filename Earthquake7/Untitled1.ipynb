# %%
# %run train.py
# Out:
# load in 18.268252849578857 sec
# seismic.shape, fault.shape (350, 500, 1200) (350, 500, 1200)
# seismic.max(), seismic.min(), fault.max(), fault.min() 1.0 0.0 True False
# pixelThre  276
# horizontal_splits_number 24
# width_after_pad 1200
# left_pad,right_pad 0 0
# vertical_splits_number 10
# height_after_pad 528
# top_pad,bottom_pad 14 14
# len(Y) 48029
# len(X) 48029
# X[0].shape (96, 96)
# read images in 5.502733469009399 sec
# (48029, 96, 96)
# (48029, 96, 96)
# read images in 4.5280516147613525 sec
# (48029, 96, 96, 1)
# (48029, 96, 96, 1)
# 6779
# 6779
# (96, 96)
# read images in 0.500931978225708 sec
# (6779, 96, 96)
# (6779, 96, 96)
# read images in 0.18999266624450684 sec
# (6779, 96, 96, 1)
# (6779, 96, 96, 1)
# X_train (48029, 96, 96, 1)
# X_val (6779, 96, 96, 1)
# Y_train (48029, 96, 96, 1)
# Y_val (6779, 96, 96, 1)
# X_train (48029, 1, 96, 96)
# X_val (6779, 1, 96, 96)
# Y_train (48029, 1, 96, 96)
# Y_val (6779, 1, 96, 96)
# DeepLab(
#   (backbone): MobileNetV2(
# ...

# %%
cd /content/drive/My Drive/Earthquake/Earthquake6
# Out:
# /content/drive/My Drive/Earthquake/Earthquake6

# %%
# !python train.py -c config.json --bs 128
# Out:
# tcmalloc: large alloc 1680007168 bytes == 0x5da6000 @  0x7ff779f4f1e7 0x7ff7777735e1 0x7ff7777dcb1d 0x7ff7777dd732 0x7ff777874dbe 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d
# load in 52.110695123672485 sec
# seismic.shape, fault.shape (350, 500, 1200) (350, 500, 1200)
# seismic.max(), seismic.min(), fault.max(), fault.min() 1.0 0.0 True False
# pixelThre  276
# horizontal_splits_number 24
# width_after_pad 1200
# left_pad,right_pad 0 0
# vertical_splits_number 10
# height_after_pad 528
# top_pad,bottom_pad 14 14
# len(Y) 3224
# len(X) 3224
# X[0].shape (96, 96)
# read images in 0.3632056713104248 sec
# (3224, 96, 96)
# (3224, 96, 96)
# read images in 0.22222256660461426 sec
# (3224, 96, 96, 1)
# (3224, 96, 96, 1)
# 916
# 916
# (96, 96)
# read images in 0.06644892692565918 sec
# (916, 96, 96)
# ...

# %%
# !python save_predicted_picture.py --config config2.json
